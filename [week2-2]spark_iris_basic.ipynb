# %% [markdown]
# ### Iris 데이터 세트를 로딩하고 Pandas DataFrame으로 변환 후 scikit learn으로 학습 및 예측 수행.

# %%
# sklearn에서 사용하던 방식
from sklearn.datasets import load_iris
import pandas as pd 
import numpy as np

# iris 데이터 세트 로딩
iris = load_iris()
iris_data = iris.data
iris_label = iris.target
print(type(iris_data), type(iris_label), iris_data.shape, iris_label.shape) # numpy 객체이므로 똑같이 shape을 사용 가능함
print(iris.feature_names)

# iris 데이터 세트를 numpy에서 pandas DataFrame으로 변환 
iris_columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

iris_pdf = pd.DataFrame(iris_data, columns=iris_columns)
iris_pdf['target'] = iris_label

print(iris_pdf['target'].value_counts())
display(iris_pdf.head())
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> (150, 4) (150,)
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th></tr></thead><tbody><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td></tr><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td><td>0</td></tr></tbody></table></div>

# %%
# 의사결정나무로 이진분류를 수행
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris_data, iris_label, 
                                                    test_size=0.2, random_state=11)
# DecisionTreeClassifier 객체 생성 
dt_clf = DecisionTreeClassifier(random_state=11, max_depth=5)

# 학습 수행. fit()을 호출하면 DecisionTreeClassifier 객체가 학습 됨.  
dt_clf.fit(X_train, y_train)

# 학습이 완료된 DecisionTreeClassifier 객체에서 테스트 데이터 세트로 예측 수행. 
pred = dt_clf.predict(X_test)
print('테스트 데이터로 예측된 값:', pred)
# Out:
# 테스트 데이터로 예측된 값: [2 2 1 1 2 0 1 0 0 1 1 1 1 2 2 0 2 1 2 2 1 0 0 1 0 0 2 1 0 1]

# %% [markdown]
# ### Spark DataFrame 생성 후 ML 알고리즘 학습 및 예측 수행.
# * iris_sdf DataFrame을 randomSplit()을 이용하여 train용과 test용 DataFrame으로 분할
# * VectorAssembler를 이용하여 모든 feature 컬럼들을 하나의 feature vector로 변환
# * Estimator 객체를 생성하고, fit() 메소드를 호출하여 ML Model 반환
# * ML Model을 이용하여 테스트 DataFrame에 예측 수행.

# %%
iris_sdf = spark.createDataFrame(iris_pdf)
print(type(iris_sdf))
display(iris_sdf.limit(5))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th></tr></thead><tbody><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td></tr><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td><td>0</td></tr></tbody></table></div>

# %%
'''
iris_sdf DataFrame을 randomSplit()을 이용하여 train용과 test용 DataFrame으로 분할 
'''

train_sdf, test_sdf = iris_sdf.randomSplit([0.8, 0.2], seed=42)
train_sdf.cache() # 메모리에 고정시킴
print(iris_sdf.count(), train_sdf.count(), test_sdf.count())
# Out:
# 150 117 33

# %%
display(train_sdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th></tr></thead><tbody><tr><td>4.3</td><td>3.0</td><td>1.1</td><td>0.1</td><td>0</td></tr><tr><td>4.4</td><td>2.9</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>4.6</td><td>3.4</td><td>1.4</td><td>0.3</td><td>0</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td></tr><tr><td>4.8</td><td>3.0</td><td>1.4</td><td>0.1</td><td>0</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>5.0</td><td>3.4</td><td>1.5</td><td>0.2</td><td>0</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.3</td><td>0</td></tr><tr><td>5.4</td><td>3.9</td><td>1.3</td><td>0.4</td><td>0</td></tr><tr><td>5.4</td><td>3.9</td><td>1.7</td><td>0.4</td><td>0</td></tr><tr><td>5.7</td><td>4.4</td><td>1.5</td><td>0.4</td><td>0</td></tr><tr><td>5.8</td><td>4.0</td><td>1.2</td><td>0.2</td><td>0</td></tr><tr><td>4.7</td><td>3.2</td><td>1.6</td><td>0.2</td><td>0</td></tr><tr><td>4.8</td><td>3.1</td><td>1.6</td><td>0.2</td><td>0</td></tr><tr><td>4.8</td><td>3.4</td><td>1.9</td><td>0.2</td><td>0</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td></tr><tr><td>5.0</td><td>3.4</td><td>1.6</td><td>0.4</td><td>0</td></tr><tr><td>5.1</td><td>3.3</td><td>1.7</td><td>0.5</td><td>0</td></tr><tr><td>5.1</td><td>3.7</td><td>1.5</td><td>0.4</td><td>0</td></tr><tr><td>5.1</td><td>3.8</td><td>1.5</td><td>0.3</td><td>0</td></tr><tr><td>5.2</td><td>3.4</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>5.2</td><td>3.5</td><td>1.5</td><td>0.2</td><td>0</td></tr><tr><td>5.2</td><td>4.1</td><td>1.5</td><td>0.1</td><td>0</td></tr><tr><td>5.4</td><td>3.4</td><td>1.7</td><td>0.2</td><td>0</td></tr><tr><td>5.5</td><td>3.5</td><td>1.3</td><td>0.2</td><td>0</td></tr><tr><td>5.5</td><td>4.2</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>4.4</td><td>3.0</td><td>1.3</td><td>0.2</td><td>0</td></tr><tr><td>4.5</td><td>2.3</td><td>1.3</td><td>0.3</td><td>0</td></tr><tr><td>4.6</td><td>3.2</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>4.8</td><td>3.0</td><td>1.4</td><td>0.3</td><td>0</td></tr><tr><td>4.9</td><td>3.6</td><td>1.4</td><td>0.1</td><td>0</td></tr><tr><td>5.0</td><td>3.3</td><td>1.4</td><td>0.2</td><td>0</td></tr><tr><td>5.0</td><td>3.5</td><td>1.6</td><td>0.6</td><td>0</td></tr><tr><td>5.3</td><td>3.7</td><td>1.5</td><td>0.2</td><td>0</td></tr><tr><td>5.5</td><td>2.3</td><td>4.0</td><td>1.3</td><td>1</td></tr><tr><td>5.7</td><td>2.8</td><td>4.5</td><td>1.3</td><td>1</td></tr><tr><td>6.4</td><td>3.2</td><td>4.5</td><td>1.5</td><td>1</td></tr><tr><td>6.5</td><td>2.8</td><td>4.6</td><td>1.5</td><td>1</td></tr><tr><td>6.9</td><td>3.1</td><td>4.9</td><td>1.5</td><td>1</td></tr><tr><td>7.0</td><td>3.2</td><td>4.7</td><td>1.4</td><td>1</td></tr><tr><td>4.9</td><td>2.4</td><td>3.3</td><td>1.0</td><td>1</td></tr><tr><td>5.0</td><td>2.0</td><td>3.5</td><td>1.0</td><td>1</td></tr><tr><td>5.2</td><td>2.7</td><td>3.9</td><td>1.4</td><td>1</td></tr><tr><td>5.6</td><td>2.5</td><td>3.9</td><td>1.1</td><td>1</td></tr><tr><td>5.6</td><td>2.9</td><td>3.6</td><td>1.3</td><td>1</td></tr><tr><td>5.6</td><td>3.0</td><td>4.5</td><td>1.5</td><td>1</td></tr><tr><td>5.8</td><td>2.7</td><td>4.1</td><td>1.0</td><td>1</td></tr><tr><td>5.9</td><td>3.0</td><td>4.2</td><td>1.5</td><td>1</td></tr><tr><td>6.0</td><td>2.2</td><td>4.0</td><td>1.0</td><td>1</td></tr><tr><td>6.1</td><td>2.8</td><td>4.0</td><td>1.3</td><td>1</td></tr><tr><td>6.1</td><td>2.8</td><td>4.7</td><td>1.2</td><td>1</td></tr><tr><td>6.1</td><td>2.9</td><td>4.7</td><td>1.4</td><td>1</td></tr><tr><td>6.2</td><td>2.2</td><td>4.5</td><td>1.5</td><td>1</td></tr><tr><td>6.3</td><td>2.5</td><td>4.9</td><td>1.5</td><td>1</td></tr><tr><td>6.3</td> ...

# %%
# VectorAssembler를 이용하여 모든 feature 컬럼들을 하나의 feature vector로 변환(모음).
from pyspark.ml.feature import VectorAssembler

iris_columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
vec_assembler = VectorAssembler(inputCols=iris_columns, outputCol='features') # VectorAssembler() 생성 인자로 outputCols가 아닌 outputCol이 입력됨에 유의
# Java의 convention을 따라가다보니 함수의 parameter 이름이 input_cols (python) 이 아닌 inputCols (java)와 같이 naming 되어 있다.
'''
VectorAssembler 객체의 transform() 메소드를 호출하여 모든 feature 컬럼을 하나의 feature vector로 변환. 
단 VectorAssembler(inputCols=iris_columns, outputCol='features').transform(DataFrame)으로 반환되는 DataFrame은 기존 DataFrame에 outputCol로 지정된 컬럼이 추가된 DataFrame임 
'''
train_feature_vector_df = vec_assembler.transform(train_sdf)

print(type(train_feature_vector_df))
display(train_feature_vector_df)
# vectorType : "dense" -> 칼럼이 많고 0이 많은 경우 "sparse"로 해야 메모리 공간이 낭비된다.
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th><th>features</th></tr></thead><tbody><tr><td>4.3</td><td>3.0</td><td>1.1</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.3, 3.0, 1.1, 0.1))</td></tr><tr><td>4.4</td><td>2.9</td><td>1.4</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.4, 2.9, 1.4, 0.2))</td></tr><tr><td>4.6</td><td>3.4</td><td>1.4</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.4, 1.4, 0.3))</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.7, 3.2, 1.3, 0.2))</td></tr><tr><td>4.8</td><td>3.0</td><td>1.4</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.0, 1.4, 0.1))</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.9, 3.0, 1.4, 0.2))</td></tr><tr><td>5.0</td><td>3.4</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.4, 1.5, 0.2))</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.6, 1.4, 0.2))</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.5, 1.4, 0.2))</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.5, 1.4, 0.3))</td></tr><tr><td>5.4</td><td>3.9</td><td>1.3</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.9, 1.3, 0.4))</td></tr><tr><td>5.4</td><td>3.9</td><td>1.7</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.9, 1.7, 0.4))</td></tr><tr><td>5.7</td><td>4.4</td><td>1.5</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 4.4, 1.5, 0.4))</td></tr><tr><td>5.8</td><td>4.0</td><td>1.2</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.8, 4.0, 1.2, 0.2))</td></tr><tr><td>4.7</td><td>3.2</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.7, 3.2, 1.6, 0.2))</td></tr><tr><td>4.8</td><td>3.1</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.1, 1.6, 0.2))</td></tr><tr><td>4.8</td><td>3.4</td><td>1.9</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.4, 1.9, 0.2))</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.9, 3.1, 1.5, 0.2))</td></tr><tr><td>5.0</td><td>3.4</td><td>1.6</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.4, 1.6, 0.4))</td></tr><tr><td>5.1</td><td>3.3</td><td>1.7</td><td>0.5</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.3, 1.7, 0.5))</td></tr><tr><td>5.1</td><td>3.7</td><td>1.5</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.7, 1.5, 0.4))</td></tr><tr><td>5.1</td><td>3.8</td><td>1.5</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.8, 1.5, 0.3))</td></tr><tr><td>5.2</td><td>3.4</td><td>1.4</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.2, 3.4, 1.4, 0.2))</td></tr><tr><td>5.2</td><td>3.5</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.2, 3.5, 1.5, 0.2))</td></tr><tr><td>5.2</td><td>4.1</td><td>1.5</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.2, 4.1, 1.5, 0.1))</td></tr><tr><td>5.4</td><td>3.4</t ...

# %% [markdown]
# #### pyspark.ml.classification.DecisionTreeClassifier

# %%
from pyspark.ml.classification import DecisionTreeClassifier

# Decision Tree 로 학습 수행. 
dt = DecisionTreeClassifier(featuresCol='features', labelCol='target', maxDepth=5)

# ML 알고리즘 객체의 fit()메소드를 이용하여 train feature vector 데이터 세트를 학습하고 이를 ML Model로 반환함.
# scikit learn은 ML 알고리즘 객체로 fit()만 호출하면 해당 객체가 학습이 되었으나 Spark ML을 반드시 ML Model로 반환 받아야 함. 
dt_model = dt.fit(train_feature_vector_df) #dt.fit(X_train, y_label) -> scikit-learn에서는 fit을 하면 dt라는 estimator 객체 자체가 학습이 이루어졌다. 하지만 pyspark에서는 model을 return하게 된다.
print('DecisionTree Estimator type:', type(dt), 'DecisionTree Estimator Model type:', type(dt_model))
print(dt)
print(dt_model)
# Out:
# DecisionTree Estimator type: <class 'pyspark.ml.classification.DecisionTreeClassifier'> DecisionTree Estimator Model type: <class 'pyspark.ml.classification.DecisionTreeClassificationModel'>
# DecisionTreeClassifier_750ff82f7f3b
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_750ff82f7f3b, depth=4, numNodes=11, numClasses=3, numFeatures=4

# %%
# 테스트 데이터를 feature vector로 변환. 학습과 동일한 형태로 바꾸기
# 학습데이터로 만들어진 vec_assembler를 그대로 사용해서 변환하기!
test_feature_vector_df = vec_assembler.transform(test_sdf)

print(type(test_feature_vector_df))
display(test_feature_vector_df)
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th><th>features</th></tr></thead><tbody><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.1, 1.5, 0.2))</td></tr><tr><td>4.8</td><td>3.4</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.4, 1.6, 0.2))</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.9, 3.1, 1.5, 0.1))</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.7, 1.5, 0.2))</td></tr><tr><td>4.6</td><td>3.6</td><td>1.0</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.6, 1.0, 0.2))</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.0, 1.6, 0.2))</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.2, 1.2, 0.2))</td></tr><tr><td>5.4</td><td>3.4</td><td>1.5</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.4, 1.5, 0.4))</td></tr><tr><td>5.7</td><td>3.8</td><td>1.7</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 3.8, 1.7, 0.3))</td></tr><tr><td>4.4</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.4, 3.2, 1.3, 0.2))</td></tr><tr><td>5.0</td><td>3.5</td><td>1.3</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.5, 1.3, 0.3))</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.4, 1.5, 0.2))</td></tr><tr><td>5.1</td><td>3.8</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.8, 1.6, 0.2))</td></tr><tr><td>5.1</td><td>3.8</td><td>1.9</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.8, 1.9, 0.4))</td></tr><tr><td>5.9</td><td>3.2</td><td>4.8</td><td>1.8</td><td>1</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.9, 3.2, 4.8, 1.8))</td></tr><tr><td>5.7</td><td>2.6</td><td>3.5</td><td>1.0</td><td>1</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 2.6, 3.5, 1.0))</td></tr><tr><td>6.8</td><td>2.8</td><td>4.8</td><td>1.4</td><td>1</td><td>Map(vectorType -> dense, length -> 4, values -> List(6.8, 2.8, 4.8, 1.4))</td></tr><tr><td>5.1</td><td>2.5</td><td>3.0</td><td>1.1</td><td>1</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 2.5, 3.0, 1.1))</td></tr><tr><td>5.7</td><td>2.9</td><td>4.2</td><td>1.3</td><td>1</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 2.9, 4.2, 1.3))</td></tr><tr><td>5.8</td><td>2.7</td><td>5.1</td><td>1.9</td><td>2</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.8, 2.7, 5.1, 1.9))</td></tr><tr><td>6.2</td><td>2.9</td><td>4.3</td><td>1.3</td><td>1</td><td>Map(vectorType -> dense, length -> 4, values -> List(6.2, 2.9, 4.3, 1.3))</td></tr><tr><td>6.4</td><td>2.7</td><td>5.3</td><td>1.9</td><td>2</td><td>Map(vectorType -> dense, length -> 4, values -> List(6.4, 2.7, 5.3, 1.9))</td></tr><tr><td>6.5</td><td>3.0</td><td>5.8</td><td>2.2</td><td>2</td><td>Map(vectorType -> dense, length -> 4, values -> List(6.5, 3.0, 5.8, 2.2))</td></tr><tr><td>7.3</td><td>2.9</td><td>6.3</td><td>1.8</td><td>2</td><td>Map(vectorType -> dense, length -> 4, values -> List(7.3, 2.9, 6.3, 1.8))</td></tr><tr><td>6.1</td><td>3.0</td><td>4.9</td><td>1.8</td><td>2</td><td>Map(vectorType -> dense, length -> 4, values -> List(6.1, 3.0, 4.9, 1.8))</td></tr><tr><td>6.4</td><td>2.8</t ...

# %%
# 테스트 데이터 + 변환된 feature vector로 구성된 DataFrame을 학습된 모델의 transform() 메소드를 이용하여 예측 수행. 
# 학습된 모델은 ML 알고리즘 객체의 생성자로 featuresCols인자로 'features' 컬럼이 주어졌으므로 feature vector컬럼명을 인지하고 있음. 
# transform() 수행 결과로 입력 DataFrame에 rawPrediction, probability, prediction 3개의 컬럼이 추가.
# rawPrediction은 ML 알고리즘 별로 다를 수 있음. Logistic Regression의 경우 예측 label 별로, 예측 수행 전 sigmoid함수 적용 전 값. 
# probability는 예측 label별 예측 확률값, prediction은 최종 예측 값. 
predictions = dt_model.transform(test_feature_vector_df)
print(type(predictions))
display(predictions)
# raw_prediction은 Decision Tree의 Entropy?
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th><th>features</th><th>rawPrediction</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.1, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.8</td><td>3.4</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.4, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.9, 3.1, 1.5, 0.1))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.7, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.6</td><td>3.6</td><td>1.0</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.6, 1.0, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.0, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.2, 1.2, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.4</td><td>1.5</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.4, 1.5, 0.4))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.7</td><td>3.8</td><td>1.7</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 3.8, 1.7, 0.3))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.4</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.4, 3.2, 1.3, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.5</td><td>1.3</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.5, 1.3, 0.3))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.4, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0. ...

# %% [markdown]
# #### pyspark.ml.classification.LogisticRegression

# %%
# LogisitcRegression으로 예측 진행하기
from pyspark.ml.classification import LogisticRegression

# ML 알고리즘 객체 생성. 
lr = LogisticRegression(featuresCol='features', labelCol='target', maxIter=10)

# ML 알고리즘 객체의 fit()메소드를 이용하여 train feature vector 데이터 세트를 학습하고 이를 ML Model로 반환함.
# scikit learn은 ML 알고리즘 객체로 fit()만 호출하면 해당 객체가 학습이 되었으나 Spark ML을 반드시 ML Model로 반환 받아야 함. 
lr_model = lr.fit(train_feature_vector_df)

predictions = lr_model.transform(test_feature_vector_df)
print(type(predictions))
display(predictions)
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th><th>features</th><th>rawPrediction</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.1, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(16.013214892108593, 7.067305854760584, -23.08052074686917))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9998697479707581, 1.302520292417766E-4, 1.0513559178302333E-17))</td><td>0.0</td></tr><tr><td>4.8</td><td>3.4</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.4, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(16.761611524054125, 7.249393207941973, -24.011004731996096))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9999260626360437, 7.393736395631259E-5, 1.961758917585887E-18))</td><td>0.0</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.9, 3.1, 1.5, 0.1))</td><td>Map(vectorType -> dense, length -> 3, values -> List(15.493805867674808, 8.28808753901145, -23.781893406686255))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9992582218747165, 7.417781252833945E-4, 8.759075353755944E-18))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.7, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(16.601362768365508, 8.788086685614324, -25.389449453979832))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9995958321646691, 4.041678353309836E-4, 5.800245794452775E-19))</td><td>0.0</td></tr><tr><td>4.6</td><td>3.6</td><td>1.0</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.6, 1.0, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(20.47512779964656, 6.860197417055079, -27.335325216701634))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9999987778899021, 1.2221100980097582E-6, 1.7225964463539155E-21))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.0, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(13.622415555462775, 8.316553408216329, -21.938968963679102))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.995062085945253, 0.004937914054746426, 3.57879740263769E-16))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.2, 1.2, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(15.996952085982032, 8.38249029171044, -24.37944237769247))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9995069771019964, 4.930228980036317E-4, 2.9143420011970004E-18))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.4</td><td>1.5</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.4, 1.5, 0.4))</td><td>Map(vectorType -> dense, length -> 3, values -> List(13.60006499125906, 8.505697566472339, -22.105762557731396))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9939061784966107, 0.006093821503389084, 3.093866101237759E-16))</td><td>0.0</td></tr><tr><td>5.7</td><td>3.8</td><td>1.7</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 3.8, 1.7, 0.3))</td><td>Map(vectorType -> dense, length -> 3, values -> List(14.880872190343451, 9.114451724829859, -23.995323915173305))</td><td>Map(vectorType -> dense, length -> 3, values -> List(0.9968788274146133, 0.0031211725853865363, 1.302941527409468E-17))</td><td>0.0</td></tr><tr ...

# %% [markdown]
# #### Evaluation

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator_accuracy = MulticlassClassificationEvaluator(labelCol='target', predictionCol='prediction', metricName='accuracy')
accuracy = evaluator_accuracy.evaluate(predictions)
print('정확도:', accuracy)
# Out:
# 정확도: 0.9696969696969697

# %% [markdown]
# ### Pipeline 적용하기
# * Pipeline은 여러개의 개별적인 Transformer의 변환 작업, Estimator의 학습 작업을 일련의 Process 연결을 통해 간단한 API 처리로 구현할 수 있게 만들어 줌
# * Pipeline은 개별 변환 및 학습 작업을 Stage로 각각 정의하여 Pipeline에 등록한 뒤 Pipeline의 fit() 메소드를 호출하여 연결된 Stage 작업을 수행. 수행 결과로 PipelineModel이 반환되며, 이 PipelineModel에서 예측을 위한 변환 및 예측 작업을 transform() 메소드로 수행.

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import DecisionTreeClassifier

iris_columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
# 첫번째 stage는 Feature Vectorization을 위해 VectorAssembler 객체 생성. 
stage_1 = VectorAssembler(inputCols=iris_columns, outputCol='features')
# 두번째 stage는 학습을 위한 결정 트리 Estimator 생성.  
stage_2 = DecisionTreeClassifier(featuresCol='features', labelCol='target', maxDepth=5)

# Feature Vectorization 변환-> 학습 pipeline을 생성. 
pipeline = Pipeline(stages=[stage_1, stage_2])

# Estimator가 포함된 Pipeline객체의 fit(train_sdf)를 호출하면 학습 데이터에 transformation을 적용하여 Estimator의 학습까지 수행된 PipelineModel 객체를 반환.
pipeline_model = pipeline.fit(train_sdf) # train_sdf_vectorized = stage_1.transform(train_sdf) , estimator_model = stage_2.fit(train_sdf_vectorized)

print(type(pipeline), type(pipeline_model))
# Out:
# <class 'pyspark.ml.pipeline.Pipeline'> <class 'pyspark.ml.pipeline.PipelineModel'>

# %%
# Pipeline Model은 feature vectorization 객체, EstimatorModel을 가지고 있으므로 이를 이용하여 테스트 데이터의 변환->예측 수행
predictions = pipeline_model.transform(test_sdf) # test_sdf_vectorized = stage_1.transform(test_sdf), estimator_model.transform(test_sdf_vectorized)
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol='target', predictionCol='prediction', metricName='accuracy')
accuracy = evaluator_accuracy.evaluate(predictions)
print('정확도:', accuracy)

display(predictions)
# Out:
# 정확도: 0.9393939393939394
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th><th>features</th><th>rawPrediction</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.1, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.8</td><td>3.4</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.4, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.9, 3.1, 1.5, 0.1))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.7, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.6</td><td>3.6</td><td>1.0</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.6, 1.0, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.0, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.2, 1.2, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.4</td><td>1.5</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.4, 1.5, 0.4))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.7</td><td>3.8</td><td>1.7</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 3.8, 1.7, 0.3))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.4</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.4, 3.2, 1.3, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.5</td><td>1.3</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.5, 1.3, 0.3))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.4, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0. ...

# %%
# stages 속성은 pipeline_model이 가지는 stage별 객체를 리스트로 가지고 있음. 
pipeline_model.stages
# DecisionTreeClassificationModel은 fit을 하는 순간에 추가됨.
# Out:
# Out[15]: [VectorAssembler_30836b99cb9c,
#  DecisionTreeClassificationModel: uid=DecisionTreeClassifier_74e21156dcfc, depth=4, numNodes=11, numClasses=3, numFeatures=4]

# %%
# PipelineModel의 stages 속성에서 개별 stage에 있는 객체를 가져 올 수 있음. 
vector_assembler = pipeline_model.stages[0]
dt_model = pipeline_model.stages[-1]

print(dt_model)
print(vector_assembler)
# Out:
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_74e21156dcfc, depth=4, numNodes=11, numClasses=3, numFeatures=4
# VectorAssembler_30836b99cb9c

# %%
test_feature_vector_df = vec_assembler.transform(test_sdf)
predictions = dt_model.transform(test_feature_vector_df)

accuracy = evaluator_accuracy.evaluate(predictions)
print('정확도:', accuracy)

display(predictions)
# Out:
# 정확도: 0.9393939393939394
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal_length</th><th>sepal_width</th><th>petal_length</th><th>petal_width</th><th>target</th><th>features</th><th>rawPrediction</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.1, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.8</td><td>3.4</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.8, 3.4, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.9, 3.1, 1.5, 0.1))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.7, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.6</td><td>3.6</td><td>1.0</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.6, 3.6, 1.0, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.0</td><td>1.6</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.0, 1.6, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.2</td><td>1.2</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.2, 1.2, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.4</td><td>3.4</td><td>1.5</td><td>0.4</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.4, 3.4, 1.5, 0.4))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.7</td><td>3.8</td><td>1.7</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.7, 3.8, 1.7, 0.3))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>4.4</td><td>3.2</td><td>1.3</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(4.4, 3.2, 1.3, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.0</td><td>3.5</td><td>1.3</td><td>0.3</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.0, 3.5, 1.3, 0.3))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0.0))</td><td>Map(vectorType -> dense, length -> 3, values -> List(1.0, 0.0, 0.0))</td><td>0.0</td></tr><tr><td>5.1</td><td>3.4</td><td>1.5</td><td>0.2</td><td>0</td><td>Map(vectorType -> dense, length -> 4, values -> List(5.1, 3.4, 1.5, 0.2))</td><td>Map(vectorType -> dense, length -> 3, values -> List(36.0, 0.0, 0. ...

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
